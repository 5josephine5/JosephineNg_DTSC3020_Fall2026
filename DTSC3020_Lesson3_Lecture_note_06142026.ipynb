# %% [markdown]
# <a href="https://colab.research.google.com/github/5josephine5/JosephineNg_DTSC3020_Fall2026/blob/main/DTSC3020_Lesson3_Lecture_note_06142026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <style>
# .jp-RenderedHTMLCommon h1 { color: #0b6b3a; border-bottom: 2px solid #dcefe5; padding-bottom: 6px; }
# .jp-RenderedHTMLCommon h2 { color: #0e5f43; margin-top: 28px; }
# .jp-RenderedHTMLCommon h3 { color: #205b85; }
# .callout { border-left: 7px solid #0b6b3a; background: #f3fbf5; padding: 14px 18px; margin: 16px 0; border-radius: 8px; }
# .warning { border-left: 7px solid #b45309; background: #fff8e6; padding: 14px 18px; margin: 16px 0; border-radius: 8px; }
# .activity { border-left: 7px solid #2563eb; background: #f2f6ff; padding: 14px 18px; margin: 16px 0; border-radius: 8px; }
# .checkpoint { border-left: 7px solid #7c3aed; background: #f8f5ff; padding: 14px 18px; margin: 16px 0; border-radius: 8px; }
# .quiz { border: 1px solid #d8e2ea; background: #fbfdff; padding: 14px 18px; margin: 16px 0; border-radius: 10px; }
# .figure { margin: 18px 0 24px 0; padding: 8px; background: #ffffff; border: 1px solid #d8e2ea; border-radius: 14px; }
# .figcap { font-size: 0.9em; color: #52616b; margin-top: 6px; }
# </style>
#
# # DTSC 3020: Introduction to Computation with Python
# ## Week 3 Lecture: Python Data Structures
#
# **Instructor:** Dr. Haihua Chen
# **Department of Data Science, University of North Texas**
#
# <div class="callout">
# <b>Big idea:</b> Data structures help us organize, search, transform, and process collections of data. Lists, tuples, sets, dictionaries, comprehensions, and slicing are essential tools for real Python applications.
# </div>

# %% [markdown]
# ## Learning Objectives
#
# By the end of Week 3, students should be able to:
#
# 1. Understand the purpose of Python data structures and when to use them.
# 2. Create and manipulate lists, tuples, sets, and dictionaries.
# 3. Explain the differences between lists and tuples.
# 4. Use sets and Boolean values to manage unique items and logical conditions.
# 5. Apply indexing and slicing to access and modify data.
# 6. Use list comprehension to write concise and efficient list operations.
# 7. Store and retrieve key-value pairs using dictionaries.
# 8. Combine multiple data structures to solve real-world problems.
# 9. Interpret simple nested data structures such as a list of dictionaries.
# 10. Use data structures to clean, summarize, and validate AI-generated or user-provided data.

# %% [markdown]
# <div class="figure"><img src="data:image/png;base64,..." alt="Data structure workflow" width="950"/><p class="figcap">Real applications often combine multiple data structures in one workflow.</p></div>

# %% [markdown]
# # Part 1. Why Data Structures Matter
#
# So far, we have worked with individual values such as numbers and strings. However, real-world data usually comes in collections:
#
# - A list of assignment scores
# - A tuple representing a fixed coordinate
# - A set of unique keywords
# - A dictionary storing a student profile
# - A list of dictionaries representing a dataset
# - A slice of a larger sequence
# - A list comprehension that transforms many values at once
#
# **Assigned reading:** [Python Data Structures — DataFlair](https://data-flair.training/blogs/python-data-structures-tutorial/)
#
# Data structures allow us to move from simple one-value programs to programs that can process many records.

# %% [markdown]
# <div class="figure"><img src="data:image/png;base64,..." alt="Choosing data structures" width="950"/><p class="figcap">Choosing the right Python data structure.</p></div>

# %% [markdown]
# ## Data Structure Selection Table
#
# | Need | Best choice | Example |
# |---|---|---|
# | Store ordered values that may change | List | Student scores |
# | Store fixed ordered values | Tuple | Coordinate, RGB color |
# | Remove duplicates or test membership | Set | Unique tags |
# | Store labeled information | Dictionary | Student profile |
# | Select part of a sequence | Slice | First 10 records |
# | Transform or filter many values | List comprehension | Clean survey responses |

# %% [markdown]
# # Part 2. Lists
#
# **Assigned reading:** [Python List with Examples — DataFlair](https://data-flair.training/blogs/python-list-examples/)
#
# A list is an ordered and mutable collection. Lists are one of the most commonly used Python data structures.
#
# Important list concepts:
#
# - Creating lists
# - Accessing items by index
# - Updating items
# - Adding items with `append()` or `insert()`
# - Removing items with `remove()`, `pop()`, or `del`
# - Sorting and reversing
# - Iterating through a list

# %%
# Creating a list
scores = [88, 92, 79, 95, 100]

print(scores)
print(type(scores))
print("First score:", scores[0])
print("Last score:", scores[-1])

# %% [markdown]
# ## Lists Are Mutable
#
# Mutable means the object can be changed after it is created.

# %%
scores = [88, 92, 79, 95, 100]

scores[2] = 85       # update one item
scores.append(98)    # add one item at the end
scores.insert(1, 90) # insert at index 1
removed = scores.pop() # remove last item and return it

print("Updated scores:", scores)
print("Removed score:", removed)

# %% [markdown]
# ## Useful List Methods

# %%
topics = ["Python", "AI", "Data Science"]

topics.append("Automation")
topics.insert(1, "Programming")
topics.sort()

print(topics)
print("Number of topics:", len(topics))
print("Index of Python:", topics.index("Python"))

# %% [markdown]
# ## Real Application Example 1: Gradebook Summary
#
# A list can store assignment scores and help calculate basic summary statistics.

# %%
scores = [88, 92, 79, 95, 100, 84, 91]

average = sum(scores) / len(scores)
highest = max(scores)
lowest = min(scores)

print("Scores:", scores)
print("Average:", round(average, 2))
print("Highest:", highest)
print("Lowest:", lowest)

# %% [markdown]
# ## Real Application Example 2: Detecting At-Risk Scores
#
# We can filter a list to identify students who may need support.

# %%
scores = [88, 55, 92, 63, 79, 95, 100, 58]

at_risk_scores = []

for score in scores:
    if score < 70:
        at_risk_scores.append(score)

print("At-risk scores:", at_risk_scores)

# %% [markdown]
# # Part 3. Python Slice
#
# **Assigned reading:** [Python Slice — DataFlair](https://data-flair.training/blogs/python-slice/)
#
# Slicing lets us select part of a sequence.
#
# General pattern:
#
# ```python
# sequence[start:stop:step]
# ```
#
# The stop position is not included.

# %% [markdown]
# <div class="figure"><img src="data:image/png;base64,..." alt="Slicing" width="950"/><p class="figcap">Indexing and slicing visualization.</p></div>

# %%
students = ["Alice", "Ben", "Carla", "David", "Eva", "Frank"]

print(students[0])
print(students[-1])
print(students[1:4])
print(students[:3])
print(students[3:])
print(students[::2])
print(students[::-1])

# %% [markdown]
# ## Real Application Example: Previewing and Splitting Data
#
# Before analyzing a dataset, we often preview a small portion.

# %%
survey_responses = [
    "Python is useful",
    "I like AI",
    "Data science is interesting",
    "Programming is challenging",
    "I want to learn automation",
    "Debugging takes practice",
    "I want more examples",
    "I like notebooks"
]

preview = survey_responses[:3]
last_two = survey_responses[-2:]

print("Preview:", preview)
print("Last two responses:", last_two)

# %% [markdown]
# # Part 4. Tuples
#
# **Assigned reading:** [Python Tuple — DataFlair](https://data-flair.training/blogs/python-tuple/)
#
# A tuple is an ordered and immutable collection. Once created, a tuple's items cannot be changed in place.
#
# Tuples are useful for:
#
# - Fixed records
# - Coordinates
# - Dates
# - RGB color values
# - Returning multiple values from a function
# - Packing and unpacking values

# %%
point = (3, 5)
rgb_color = (255, 128, 0)
date = (2026, 6, 15)

print(point)
print(rgb_color)
print(date)
print(type(point))

# %% [markdown]
# ## Tuple Packing and Unpacking

# %%
# Tuple packing
student_record = "Alice", "Data Science", 95

# Tuple unpacking
name, major, score = student_record

print(name)
print(major)
print(score)

# %% [markdown]
# ## Returning Multiple Values from a Function

# %%
def summarize_scores(scores):
    return min(scores), max(scores), sum(scores) / len(scores)

scores = [88, 92, 79, 95, 100]
lowest, highest, average = summarize_scores(scores)

print("Lowest:", lowest)
print("Highest:", highest)
print("Average:", average)

# %% [markdown]
# ## Single-Item Tuple
#
# A single-item tuple needs a comma.

# %%
not_tuple = (1)
real_tuple = (1,)

print(type(not_tuple))
print(type(real_tuple))

# %% [markdown]
# # Part 5. Tuple vs List
#
# **Assigned reading:** [Python Tuples vs Lists — DataFlair](https://data-flair.training/blogs/python-tuples-vs-lists/)
#
# Lists and tuples are both ordered collections, but the key difference is mutability.

# %% [markdown]
# ## List vs Tuple Summary
#
# | Feature | List | Tuple |
# |---|---|---|
# | Syntax | `[ ]` | `( )` |
# | Ordered | Yes | Yes |
# | Mutable | Yes | No |
# | Allows duplicates | Yes | Yes |
# | Common use | Changing collections | Fixed records |
# | Example | scores | coordinates |

# %%
# List: scores can change
scores = [80, 90, 95]
scores[0] = 85
scores.append(100)
print(scores)

# Tuple: coordinate should stay fixed
coordinate = (3, 5)
print(coordinate)

# coordinate[0] = 4  # This would cause an error

# %% [markdown]
# # Part 6. Sets and Booleans
#
# **Assigned reading:** [Python Set and Booleans — DataFlair](https://data-flair.training/blogs/python-set-and-booleans-with-examples/)
#
# A set is an unordered collection of unique values. Sets are useful for removing duplicates and comparing groups.

# %%
topics = {"Python", "AI", "Data Science", "Python", "AI"}

print(topics)
print("Python" in topics)
print("Java" in topics)

# %% [markdown]
# ## Removing Duplicates
#
# This is one of the most common beginner-friendly uses of sets.

# %%
raw_tags = ["AI", "Python", "AI", "Data", "Python", "Health"]
unique_tags = set(raw_tags)

print("Original tags:", raw_tags)
print("Unique tags:", unique_tags)

# %% [markdown]
# ## Set Operations
#
# Set operations are useful in recommendation systems, survey analysis, and comparing groups.

# %%
group_a = {"Alice", "Ben", "Carla"}
group_b = {"Carla", "David", "Eva"}

print("Union:", group_a | group_b)
print("Intersection:", group_a & group_b)
print("Only in A:", group_a - group_b)
print("Symmetric difference:", group_a ^ group_b)

# %% [markdown]
# ## Real Application Example: Comparing Skills
#
# Suppose two students list the tools they know. Sets can quickly show shared and unique skills.

# %%
student_a_skills = {"Python", "Excel", "SQL", "AI"}
student_b_skills = {"Python", "Tableau", "SQL", "Statistics"}

shared_skills = student_a_skills & student_b_skills
a_only = student_a_skills - student_b_skills
b_only = student_b_skills - student_a_skills

print("Shared skills:", shared_skills)
print("Only student A:", a_only)
print("Only student B:", b_only)

# %% [markdown]
# ## Booleans
#
# Booleans represent truth values: `True` or `False`.

# %%
score = 85
passed = score >= 70

print(passed)
print(type(passed))

if passed:
    print("The student passed.")
else:
    print("The student did not pass.")

# %% [markdown]
# # Part 7. Dictionaries
#
# **Assigned reading:** [Python Dictionary — DataFlair](https://data-flair.training/blogs/python-dictionary/)
#
# A dictionary stores key-value pairs. It is one of the most important data structures for real applications.
#
# Common uses:
#
# - Student profiles
# - Configuration settings
# - Word counts
# - JSON-like data
# - API responses
# - Database-like records

# %% [markdown]
# <div class="figure"><img src="data:image/png;base64,..." alt="Improved Dictionary Key-Value Lookup" width="950"/><p class="figcap">Dictionary key-value lookup model with cleaner spacing and larger text.</p></div>

# %%
student = {
    "name": "Alice",
    "major": "Data Science",
    "score": 95,
    "passed": True
}

print(student)
print(student["name"])
print(student["score"])

# %% [markdown]
# ## Updating and Adding Dictionary Values

# %%
student = {
    "name": "Alice",
    "major": "Data Science",
    "score": 95
}

student["score"] = 98
student["email"] = "alice@unt.edu"

print(student)

# %% [markdown]
# ## Safer Lookup with get()

# %%
student = {"name": "Alice", "score": 95}

print(student.get("name"))
print(student.get("email", "No email found"))

# %% [markdown]
# ## Real Application Example: Word Frequency Counter
#
# A dictionary is often used for counting.

# %%
text = "python ai python data ai python"
words = text.split()

word_counts = {}

for word in words:
    if word in word_counts:
        word_counts[word] += 1
    else:
        word_counts[word] = 1

print(word_counts)

# %% [markdown]
# ## More Concise Counting with get()

# %%
text = "python ai python data ai python"
words = text.split()

word_counts = {}

for word in words:
    word_counts[word] = word_counts.get(word, 0) + 1

print(word_counts)

# %% [markdown]
# # Part 8. Nested Data Structures
#
# Real data rarely uses only one structure. A common pattern is a **list of dictionaries**.

# %% [markdown]
# <div class="figure"><img src="data:image/png;base64,..." alt="Improved Nested Data Structures" width="950"/><p class="figcap">A list of dictionaries is common in JSON, APIs, spreadsheets, and data science workflows.</p></div>

# %%
students = [
    {"name": "Alice", "major": "Data Science", "score": 95},
    {"name": "Ben", "major": "Business", "score": 88},
    {"name": "Carla", "major": "Data Science", "score": 91},
    {"name": "David", "major": "Health Informatics", "score": 84}
]

print(students[0])
print(students[0]["name"])
print(students[2]["score"])

# %% [markdown]
# ## Real Application Example: Summarize a Small Dataset

# %%
students = [
    {"name": "Alice", "major": "Data Science", "score": 95},
    {"name": "Ben", "major": "Business", "score": 88},
    {"name": "Carla", "major": "Data Science", "score": 91},
    {"name": "David", "major": "Health Informatics", "score": 84}
]

scores = [student["score"] for student in students]
majors = {student["major"] for student in students}

print("Average score:", sum(scores) / len(scores))
print("Unique majors:", majors)

# %% [markdown]
# # Part 9. List Comprehension
#
# **Assigned reading:** [Python List Comprehension — DataFlair](https://data-flair.training/blogs/python-list-comprehension/)
#
# A list comprehension is a concise way to create a new list from an existing sequence.

# %% [markdown]
# <div class="figure"><img src="data:image/png;base64,..." alt="Comprehension pattern" width="950"/><p class="figcap">List comprehension transforms and filters data concisely.</p></div>

# %% [markdown]
# ## Traditional Loop vs List Comprehension

# %%
numbers = [1, 2, 3, 4, 5]

# Traditional loop
squares_loop = []
for n in numbers:
    squares_loop.append(n * n)

# List comprehension
squares_comp = [n * n for n in numbers]

print(squares_loop)
print(squares_comp)

# %% [markdown]
# ## Filtering with List Comprehension

# %%
scores = [55, 72, 88, 40, 95, 67]

passing_scores = [score for score in scores if score >= 70]

print(passing_scores)

# %% [markdown]
# ## Real Application Example: Clean Survey Responses

# %%
responses = [" Python ", "AI", " data science ", "PYTHON", "ai ", ""]

cleaned = [response.strip().lower() for response in responses if response.strip() != ""]

print(cleaned)

# %% [markdown]
# # Part 10. Generative AI-Era Examples
#
# ## Example 1: Clean AI-Generated Topic Lists
#
# Suppose a GenAI tool generates a list of course topics, but there are duplicates and inconsistent capitalization.

# %%
ai_topics = ["Python", "AI", "python", "Data Science", "AI", "data science", "  Python  "]

clean_topics = [topic.strip().lower() for topic in ai_topics]
unique_topics = set(clean_topics)

print("Cleaned topics:", clean_topics)
print("Unique topics:", unique_topics)

# %% [markdown]
# ## Example 2: Convert Semi-Structured AI Output into a Dictionary
#
# AI may produce text, but Python can help structure it.

# %%
student_text = "name=Alice;major=Data Science;score=95"

parts = student_text.split(";")
student = {}

for part in parts:
    key, value = part.split("=")
    student[key] = value

print(student)
print(student["major"])

# %% [markdown]
# ## Example 3: Validate AI-Generated Records
#
# Suppose an AI system generates student records. We can check whether each record contains required keys.

# %%
records = [
    {"name": "Alice", "major": "Data Science", "score": 95},
    {"name": "Ben", "score": 88},
    {"name": "Carla", "major": "Data Science", "score": 91}
]

required_keys = {"name", "major", "score"}

for record in records:
    missing_keys = required_keys - set(record.keys())
    if missing_keys:
        print("Incomplete record:", record, "| Missing:", missing_keys)
    else:
        print("Complete record:", record)

# %% [markdown]
# ## Example 4: Simple Recommendation Lookup
#
# A dictionary can power a simple recommendation system.

# %%
resource_recommendations = {
    "list": "Use lists for ordered, changeable data.",
    "tuple": "Use tuples for fixed records.",
    "set": "Use sets to remove duplicates.",
    "dictionary": "Use dictionaries for key-value lookup."
}

topic = "dictionary"
print(resource_recommendations.get(topic, "Topic not found."))

# %% [markdown]
# # Part 11. Applied Mini Case Study: Course Feedback Analyzer
#
# In this mini case, we use several data structures together to analyze student feedback.

# %%
feedback = [
    "Python is useful",
    "I like Python examples",
    "AI examples are interesting",
    "I need more practice",
    "Python and AI are useful",
    "Examples help me learn"
]

# Step 1: Combine all feedback into one text
all_text = " ".join(feedback).lower()

# Step 2: Split into words
words = all_text.split()

# Step 3: Count words using a dictionary
word_counts = {}

for word in words:
    word_counts[word] = word_counts.get(word, 0) + 1

# Step 4: Extract unique words using a set
unique_words = set(words)

print("Word counts:", word_counts)
print("Unique words:", unique_words)
print("Number of unique words:", len(unique_words))

# %% [markdown]
# ## Mini Case Reflection
#
# This small example used:
#
# - List: store multiple feedback responses
# - String: combine and process text
# - Dictionary: count words
# - Set: identify unique words
# - Loop: process each word

# %% [markdown]
# # Part 12. In-Class Activities
#
# ## Activity 1: Student Score Manager
#
# Create a list of scores, update one score, add one new score, and calculate the average.

# %%
scores = [80, 90, 85]

# update one score
scores[0] = 88

# add one new score
scores.append(95)

average = sum(scores) / len(scores)

print(scores)
print("Average:", average)

# %% [markdown]
# ## Activity 2: Duplicate Remover
#
# Given a list of tags, remove duplicates using a set.

# %%
tags = ["AI", "Python", "AI", "Data", "Python", "Health"]

unique_tags = set(tags)

print(unique_tags)

# %% [markdown]
# ## Activity 3: Student Profile Dictionary
#
# Create a dictionary with your name, major, and career goal.

# %%
profile = {
    "name": "Your Name",
    "major": "Your Major",
    "career_goal": "Your Career Goal"
}

print(profile)
print(profile["career_goal"])

# %% [markdown]
# ## Activity 4: List Comprehension Practice
#
# Create a list of numbers from 1 to 10 and use list comprehension to keep only even numbers.

# %%
numbers = list(range(1, 11))

even_numbers = [n for n in numbers if n % 2 == 0]

print(even_numbers)

# %% [markdown]
# ## Activity 5: Build a Small Course Dataset
#
# Create a list of dictionaries representing three students. Then print each student's name and score.

# %%
students = [
    {"name": "Alice", "score": 95},
    {"name": "Ben", "score": 88},
    {"name": "Carla", "score": 91}
]

for student in students:
    print(student["name"], "earned", student["score"])

# %% [markdown]
# # Part 13. Click-to-Reveal Quiz
#
# Try each question first, then click to reveal the answer.

# %% [markdown]
# <div class="quiz">
# <p><b>Question 1. Which data structure is ordered and mutable?</b></p>
#
# - A. Tuple
# - B. List
# - C. Set
# - D. Boolean
#
# <details>
# <summary><b>Click to reveal answer</b></summary>
#
# <b>Answer:</b> B. List
#
# <br><br><b>Explanation:</b> A list keeps order and can be changed after creation.
# </details>
# </div>

# %% [markdown]
# <div class="quiz">
# <p><b>Question 2. Which data structure removes duplicates automatically?</b></p>
#
# - A. List
# - B. Tuple
# - C. Set
# - D. String
#
# <details>
# <summary><b>Click to reveal answer</b></summary>
#
# <b>Answer:</b> C. Set
#
# <br><br><b>Explanation:</b> A set stores unique values and removes repeated items.
# </details>
# </div>

# %% [markdown]
# <div class="quiz">
# <p><b>Question 3. What is the main difference between a list and a tuple?</b></p>
#
# - A. Lists use keys
# - B. Tuples are mutable
# - C. Lists are mutable and tuples are immutable
# - D. Tuples cannot store numbers
#
# <details>
# <summary><b>Click to reveal answer</b></summary>
#
# <b>Answer:</b> C. Lists are mutable and tuples are immutable
#
# <br><br><b>Explanation:</b> Lists can be changed item by item; tuples cannot.
# </details>
# </div>

# %% [markdown]
# <div class="quiz">
# <p><b>Question 4. What does a dictionary store?</b></p>
#
# - A. Only numbers
# - B. Key-value pairs
# - C. Only Boolean values
# - D. Only ordered slices
#
# <details>
# <summary><b>Click to reveal answer</b></summary>
#
# <b>Answer:</b> B. Key-value pairs
#
# <br><br><b>Explanation:</b> A dictionary lets us look up values by keys.
# </details>
# </div>

# %% [markdown]
# <div class="quiz">
# <p><b>Question 5. What does `numbers[1:4]` return?</b></p>
#
# - A. Items from index 1 through 4
# - B. Items from index 1 through 3
# - C. Only index 4
# - D. The whole list
#
# <details>
# <summary><b>Click to reveal answer</b></summary>
#
# <b>Answer:</b> B. Items from index 1 through 3
#
# <br><br><b>Explanation:</b> In Python slicing, the stop index is excluded.
# </details>
# </div>

# %% [markdown]
# <div class="quiz">
# <p><b>Question 6. Why use list comprehension?</b></p>
#
# - A. To make code longer
# - B. To create lists more concisely
# - C. To delete dictionaries
# - D. To make tuples mutable
#
# <details>
# <summary><b>Click to reveal answer</b></summary>
#
# <b>Answer:</b> B. To create lists more concisely
#
# <br><br><b>Explanation:</b> List comprehension can replace simple loops that build lists.
# </details>
# </div>

# %% [markdown]
# <div class="quiz">
# <p><b>Question 7. What is a common structure for JSON-like records?</b></p>
#
# - A. A list of dictionaries
# - B. A Boolean only
# - C. A string only
# - D. A single integer
#
# <details>
# <summary><b>Click to reveal answer</b></summary>
#
# <b>Answer:</b> A. A list of dictionaries
#
# <br><br><b>Explanation:</b> Many real datasets and API responses use a list of records, where each record is represented as a dictionary.
# </details>
# </div>

# %% [markdown]
# # Part 14. Exit Ticket
#
# Before the next class, answer these questions:
#
# 1. When should you use a list?
# 2. When should you use a tuple?
# 3. Why are sets useful?
# 4. What is a dictionary key?
# 5. What does slicing do?
# 6. Write one list comprehension example.
# 7. Give one real-world example where data structures are useful.
# 8. What is one benefit of using a list of dictionaries?
# 9. How can Python data structures help validate AI-generated data?

# %% [markdown]
# # Week 3 Summary
#
# Today we covered:
#
# - Python data structures
# - Lists
# - Tuples
# - Tuple vs list
# - Sets and Booleans
# - Dictionaries
# - Nested data structures
# - List comprehension
# - Python slicing
# - Real-world applications
# - GenAI-era data cleaning and validation examples
# - Applied mini case study
# - In-class activities
#
# ## Next Week
#
# **Week 4: Control Flow, Loops, Range, Switch-Case Style Logic, and Exception Handling**

# %% [markdown]
# # Complete Source List and Credits
#
# ## Assigned Week 3 Sources
#
# 1. [Python Data Structures — DataFlair](https://data-flair.training/blogs/python-data-structures-tutorial/)
# 2. [Python List with Examples — DataFlair](https://data-flair.training/blogs/python-list-examples/)
# 3. [Python Tuple — DataFlair](https://data-flair.training/blogs/python-tuple/)
# 4. [Python Tuples vs Lists — DataFlair](https://data-flair.training/blogs/python-tuples-vs-lists/)
# 5. [Python Set and Booleans — DataFlair](https://data-flair.training/blogs/python-set-and-booleans-with-examples/)
# 6. [Python List Comprehension — DataFlair](https://data-flair.training/blogs/python-list-comprehension/)
# 7. [Python Dictionary — DataFlair](https://data-flair.training/blogs/python-dictionary/)
# 8. [Python Slice — DataFlair](https://data-flair.training/blogs/python-slice/)
#
# ## Additional Reference
#
# - [Python Official Documentation — Data Structures](https://docs.python.org/3/tutorial/datastructures.html)
#
# ## Diagram Credits
#
# The diagrams in this notebook are instructor-created, high-resolution embedded PNG figures based on the assigned DataFlair Week 3 readings listed above. They are recreated for classroom use so they display reliably in Jupyter, Google Colab, and VS Code notebooks.
